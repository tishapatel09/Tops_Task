# %%
# Task1
age= 20
height= 5.2
name= "Tisha"
spotify_account= True

print(age)
print(height)
print(name)
print(spotify_account)
# Out:
# 20
# 5.2
# Tisha
# True

# %%
print(type(age))
print(type(height))
print(type(name))
print(type(spotify_account))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %%
# Task2
total_cart_amount= ['100','23.45','345','67.30']
a= float('100')
b= float('23.45')
c= float('345')
d= float('67.30')
total= sum([a, b, c, d])

# %%
print(total)
# Out:
# 535.75

# %%
# Task3
score= str(input("Enter your score: "))
score = int(score)

# %%
if score >= 50:
    print("Half century!")
else:
    print("Keep trying!")
# Out:
# Half century!

# %%
# Task4
is_premium= ("True")
is_premium= bool(is_premium)

# %%
type(is_premium)
# Out:
# bool
