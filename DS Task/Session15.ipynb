# %%
# Task1

def  get_song_duration_per_minute(total_dur,num_of_song):
    try:
        average = total_dur/num_of_song
        print(average)
    except Exception as c:
        print("This is error",c)     

get_song_duration_per_minute(120,0)
# Out:
# This is error division by zero

# %%
# Task2

def price_per_item():
    try:
        total_amount = float(input("Enter total cart amount (₹): "))
        item_count = int(input("Enter number of items: "))

        price = total_amount / item_count

        print("Price per item: ₹", price)

    except ZeroDivisionError:
        print("Error: Item count cannot be zero.")

price_per_item()
# Out:
# Price per item: ₹ 0.0

# %%
# Task3

class NoOffersApplied(Exception):
    pass


def cashback_calculator():
    try:
        total_spend = float(input("Enter total spend (₹): "))
        offers = int(input("Enter number of offers applied: "))

        if offers == 0:
            error = NoOffersApplied("No offers were applied!")
            print("Error:", error)
        else:
            cashback = total_spend / offers
            print("Average cashback per offer: ₹", cashback)

    except ValueError:
        print("Please enter valid numbers.")


cashback_calculator()
# Out:
# Please enter valid numbers.

# %%
# Task4

def calculate_average_rating(total_rating, num_reviews):
    try:
        return total_rating / num_reviews
    except ZeroDivisionError:
        print("Error: Number of reviews cannot be zero.")
        # return None or some default value if needed

print(calculate_average_rating(500,0))
print("Thank you for using the calculator")
# Out:
# Error: Number of reviews cannot be zero.
# None
# Thank you for using the calculator

# %%
# Task5

def safe_divide_for_zomato(bill_amount, num_people):
    try:
        result = bill_amount / num_people
    except ZeroDivisionError:
        print("Error: Number of people cannot be zero.")
    else:
        print("Each person should pay: ₹", result)
    finally:
        print("Split calculation done.")

safe_divide_for_zomato(500, 3)
# Out:
# Each person should pay: ₹ 166.66666666666666
# Split calculation done.
