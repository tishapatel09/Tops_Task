# %%
# Task1

min= int(input("enter your listening time(in minutes)"))

if min>120:
    print("You are a true music fan!")
else:
    print("keep listening!")
# Out:
# You are a true music fan!

# %%
# Task2

amount= int(input("enter your zomato amount:"))

if amount>300:
    print("eligible for free delivery!")
else:
    print("Delivery charges apply")
# Out:
# eligible for free delivery!

# %%
# Task3

total = int(input("enter your flipkart total amount:"))

if total>2000:
    print("you''ll get 10% discount")
elif total>1000:
    print("you'll get 5% discount!")
else:
    print("no discount available!")
# Out:
# no discount available!

# %%
# Task4
point= int(input("enter your ipl team fantacy point:"))

if point>800:
    print("Champion!")        
else:
   if point>500:
        print("Top performer!") 
   else:
        print("keep going!")
# Out:
# Top performer!
