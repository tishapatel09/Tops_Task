# %%
# Task1

def calculate_final_price(price, discount_rate):
    discount = (price * discount_rate) / 100
    final_price = price - discount
    return final_price


print(calculate_final_price(1000, 20))
# Out:
# 800.0

# %%
# Task2

def charge(amount, city="Ahmedabad"):
    if city == "Ahmedabad":
        return 0
    else:
        return 50


print(charge(500))
print(charge(500, "Surat"))
# Out:
# 0
# 50

# %%
# Task3

def format_price(price, currency="INR"):
    if currency == "INR":
        return "₹" + str(price)
    elif currency == "USD":
        return "$" + str(price)


print(format_price(500))
print(format_price(500, "USD"))
# Out:
# ₹500
# $500

# %%
# Task4

def apply_coupon(price, coupon_code=None):
    if coupon_code == "ZOMATO10":
        return price - (price * 10 / 100)
    else:
        return price


print(apply_coupon(1000, "ZOMATO10"))
print(apply_coupon(1000))
# Out:
# 900.0
# 1000
