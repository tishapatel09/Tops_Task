# %%
# Task1
item_price = 450
delivery_fee = 70
coupon_discount = 30

print(item_price)
print(delivery_fee)
print(coupon_discount)
# Out:
# 450
# 70
# 30

# %%
# Task2
price= 920
if price > 1000:
    print("You are eligible for free delivery")
else:
    print("delivery charges apply")
# Out:
# delivery charges apply

# %%
# Task3

#Task1 is for printing the item price, delivery fee, and coupon discount. 

'''Task2 checks if the price is greater than 1000 to determine
if free delivery applies or if delivery charges apply.'''
# Out:
# 'Task2 checks if the price is greater than 1000 to determine\nif free delivery applies or if delivery charges apply.'

# %%
# Task4

team_name= ("Gujarat_Titans")
runs_scored= 209
overs_played= 20

print(team_name)
print(runs_scored)
print(overs_played)
# Out:
# Gujarat_Titans
# 209
# 20
