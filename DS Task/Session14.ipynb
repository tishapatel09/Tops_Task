# %%
# Task1

# Create a text file named playlist.txt and write the names of 5 songs you listened 
# to this week, each on a new line using Python's open() function in write mode.

file = open("playlist.txt","w")
file.write("Tum ho")
file.write("\nDarkhast")
file.write("\nKhat")
file.write("\nChasni")
file.write("\nAarzu")
file.close()

# %%
# Task2

with open("playlist.txt", "r")as file:

   data = file.read()
   print(data.upper())
# Out:
# TUM HO
# DARKHAST
# KHAT
# CHASNI
# AARZU

# %%
# Task3
# using header row

import csv

file = open("ipl.csv", "r")

reader = csv.DictReader(file)

for row in reader:
    print("Match", row["match_id"], "Winner:", row["winner"])

file.close()
# Out:
# Match 1 Winner: CSK
# Match 2 Winner: KKR
# Match 3 Winner: GT
# Match 4 Winner: PBKS
# Match 5 Winner: SRH

# %%
# using index number
import csv

file = open("ipl.csv", "r")

reader = csv.reader(file)

next(reader)    # Skip the header row

for row in reader:
    print("Match", row[0], "Winner:", row[3])

file.close()
# Out:
# Match 1 Winner: CSK
# Match 2 Winner: KKR
# Match 3 Winner: GT
# Match 4 Winner: PBKS
# Match 5 Winner: SRH

# %%
# Task4

import json

with open("movies.json", "r") as file:
    movies = json.load(file)

for movie in movies:
    print("Title:", movie["title"])
    print("Rating:", movie["rating"])
# Out:
# Title: The idea of you
# Rating: 8.4
# Title: Me before you
# Rating: 7.8
# Title: khoobsurat
# Rating: 7.6

# %%
# Task5

from pathlib import Path
import json

file = Path("my_fav_apps.json")

if file.exists():
    print("File already exists.")
else:
    apps = [
        {"name": "Instagram", "category": "Social Media"},
        {"name": "Zomato", "category": "Food Delivery"},
        {"name": "Paytm", "category": "Payments"}
    ]

    with open(file, "w") as f:
        json.dump(apps, f, indent=4)

    print("File created and data written successfully.")
# Out:
# File created and data written successfully.
