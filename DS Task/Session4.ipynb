# %%
# Task1
str= "Flipkart-Sale2024"

str.lower

print(str)

str.replace("-"," ")
# Out:
# Flipkart-Sale2024
# 'Flipkart Sale2024'

# %%
# Task2
phone= " OnePlus Nord-CE 3 "

phone1=phone.strip(" ")
print(phone1)
print(phone1.upper())
phone1.replace("-",":")
# Out:
# OnePlus Nord-CE 3
# ONEPLUS NORD-CE 3
# 'OnePlus Nord:CE 3'

# %%
# Task3
product_code= "ZOMATO-Food-2026"

product_code.split("-")
# Out:
# ['ZOMATO', 'Food', '2026']

# %%
# Task4
song= "Spotify_Premium_Offer"

print(song[8:15])
# Out:
# Premium

# %%
# Task5

product = 'Myntra Shirt'
price = 799.5

print(f"Deal: {product} is available at Rs. {price} only!")
# Out:
# Deal: Myntra Shirt is available at Rs. 799.5 only!
