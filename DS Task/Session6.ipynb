# %%
# Task1
insta_followers= {
    "Shubhman_gill":"20.4M",
    "Abhishek":"11.5M",
    "Ishan_kishan":"11.3M",
    "Devdutt":"3.2M",
    "Shivam_dube":"3.1M"
    }
insta_followers
# Out:
# {'Shubhman_gill': '20.4M',
#  'Abhishek': '11.5M',
#  'Ishan_kishan': '11.3M',
#  'Devdutt': '3.2M',
#  'Shivam_dube': '3.1M'}

# %%
# Task2
insta_followers["Virat_kohli"]="273M"
insta_followers["Abhishek"]="12.1M"
insta_followers.pop("Shivam_dube")

insta_followers
# Out:
# {'Shubhman_gill': '20.4M',
#  'Abhishek': '12.1M',
#  'Ishan_kishan': '11.3M',
#  'Devdutt': '3.2M',
#  'Virat_kohli': '273M'}

# %%
# Task3
food_prices = {
    "Burger": 180,
    "Frankie": 250,
    "Pizza": 320,
    "Dosa": 150,
    "Subway": 220
}

# Display items costing more than ₹200
print("Food items costing more than ₹200:")
for item, price in food_prices.items():
    if price > 200:
        print(f"{item}: ₹{price}")
# Out:
# Food items costing more than ₹200:
# Frankie: ₹250
# Pizza: ₹320
# Subway: ₹220

# %%
# Task4

flipkart_users= {"Tisha","Jiya","Vaidi","Pankti","Prachi"}

myntra_users= {"Tisha","Vedanshi","Sejal","Pankti","Honey"}


flipkart_users.intersection(myntra_users)
# Out:
# {'Pankti', 'Tisha'}

# %%
# Task5
playlist1= {"Pritam","Atif-aslam","Arijit-Singh","Mohit-chauhan","Vishal-shekhar"}
playlist2= {"Anuv-jain","Arijit-Singh","Navjot-Ahuja","Pritam","AP-dhillon"}

playlist1.union(playlist2)
# Out:
# {'AP-dhillon',
#  'Anuv-jain',
#  'Arijit-Singh',
#  'Atif-aslam',
#  'Mohit-chauhan',
#  'Navjot-Ahuja',
#  'Pritam',
#  'Vishal-shekhar'}
