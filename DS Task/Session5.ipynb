# %%
# Task1
playlist_id= [346,456,765,234,809]
print(playlist_id)

# Task2
playlist_id.append(100)
playlist_id.extend([200,300])
print(playlist_id)
# Out:
# [346, 456, 765, 234, 809]
# [346, 456, 765, 234, 809, 100, 200, 300]

# %%
# Task3

removed_id = playlist_id.pop(4)
print(removed_id)
print(playlist_id)
# Out:
# 809
# [346, 456, 765, 234, 100, 200, 300]

# %%
# Task4

insta_filters= ("paris", "Los_angeles", "jakarta", "hyper")

# insta_filters.remove("paris")

"error: 'tuple' object has no attribute 'remove'"
# Out:
# "error: 'tuple' object has no attribute 'remove'"

# %%
# Task5

zomato_orders = ["Pizza", "Burger", "Pasta"]

ipl_teams = (
    "CSK", "MI", "RCB", "KKR", "GT",
    "RR", "LSG", "DC", "PBKS", "SRH"
)

print("Zomato Orders:", zomato_orders)
print("Use a List because orders can be added, removed, or updated.")

print("IPL Teams:", ipl_teams)
print("Use a Tuple because the team names are fixed and should not change.")
# Out:
# Zomato Orders: ['Pizza', 'Burger', 'Pasta']
# Use a List because orders can be added, removed, or updated.
# IPL Teams: ('CSK', 'MI', 'RCB', 'KKR', 'GT', 'RR', 'LSG', 'DC', 'PBKS', 'SRH')
# Use a Tuple because the team names are fixed and should not change.
